# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Task 1: Problem definition

# %% [markdown]
# ### Project Description:
# The aim of our project is to create a model that allow us to predict the price of hdb using relevant parameters, such as the flat type, size, distance form mrt, etc. We achieved this goal by following the steps below:
#     1. A suitable dataset with the relevant data and attributes is selected
#     2. Additional datasets are evaluated and used to enrich the existing dataset.
#     3. Exploratory data analysis and visualisation are done where data is cleaned and prepared
#     4. Multiple models are trained and evaluated using RMSE (Root-mean-square error) and MAE (Mean absolute error).
#     5. The selected model is analysed where the feature importance is evaluated

# %% [markdown]
# ### Potential use cases:
#
# 1) The trained model can be deployed on real estate website such as PropertyGuru, 99.co, where buyers and sellers are able to get the most optimal price estimation before listing or buying.
# 2) This model can also be used by HDB to real estate agent to find a suitable price when consulting their clients on calculating the valuation of the client's property.

# %% [markdown]
# # Task 2: Data collection/curation
#
#  We have collected the data we required for our HDB sales price prediction task primarary from data.gov.sg.
#
#  **HDB resale price** : https://beta.data.gov.sg/collections/189/datasets/d_8b84c4ee58e3cfc0ece0d773c8ca6abc/view
#
#  Besides, we also enriched our dataset using additional data from kaggle as follows:
#
# **HDB coordinate** : https://www.kaggle.com/datasets/mylee2009/singapore-postal-code-mapper
# **MRT coordinate** : https://www.kaggle.com/datasets/shengjunlim/singapore-mrt-lrt-stations-with-coordinates
#
# The files have been downloaded locally and renamed accordingly.

# %% [markdown]
# # Task 3 & 4: Data preparation & Exploratory data analysis and visualization

# %% [markdown]
# #### Step 1: Import the packages and load resale data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline


data = pd.read_csv("ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
hdb_locations = pd.read_csv("sg_zipcode_mapper_utf.csv", delimiter=',')
mrt_locations = pd.read_csv("mrt.csv")

# %% [markdown]
# #### Step 2: Data cleaning and EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177572 entries, 0 to 177571
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                177572 non-null  object
#  1   town                 177572 non-null  object
#  2   flat_type            177572 non-null  object
#  3   block                177572 non-null  object
#  4   street_name          177572 non-null  object
#  5   storey_range         177572 non-null  object
#  6   floor_area_sqm       177572 non-null  float64
#  7   flat_model           177572 non-null  object
#  8   lease_commence_date  177572 non-null  int64
#  9   remaining_lease      177572 non-null  object
#  10  resale_price         177572 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 14.9+ MB

# %%
data.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# The data is already cleaned, it does not contain null value, therefore data cleaning is not required.
#
# Extract year from the data and filter data to only include data from 2019 to 2023, because we only want to predict he proce of the flat based on the past 4 years of data.

# %%
data['month'] = pd.to_datetime(data['month'])
data['year'] = list(map(lambda x: x.year, data['month']))

data = data[data['year'] >= 2019]
data = data[data['year'] != 2024]

data['price_per_sqm'] = data['resale_price'] / data['floor_area_sqm']
data['remaining_lease'] = (99 + data['lease_commence_date']) - data['year']

# %%
flat_type_counts = data['flat_type'].value_counts(normalize=True) * 100  # This calculates the percentage

# Create a bar plot using Matplotlib
plt.bar(flat_type_counts.index, flat_type_counts.values)

plt.xlabel('Flat Type')
plt.ylabel('Percentage')
plt.title('Percentage of Flat Types')
plt.xticks(rotation=90, ha='left', rotation_mode='default')
plt.show()

# # Show the plot
# plt.show()

# %% [markdown]
# #### From the count plot above we can see that there are very little one room, two room and multi-generatin flat(below 5%). therefore we are going to drop these data for our model training.

# %%
data = data[data['flat_type'] != "1 ROOM"]
data = data[data['flat_type'] != "2 ROOM"]
data = data[data['flat_type'] != "MULTI-GENERATION"]

# %%
town_counts = data['town'].value_counts()  # Get the counts for each town
total_counts = town_counts.sum()  # Total number of entries
town_percent = (town_counts / total_counts) * 100  # Convert counts to percentage

# Plotting with Matplotlib
plt.figure(figsize=(10, 6))  # Optional: Adjust the size of the figure
plt.bar(town_percent.index, town_percent.values)  # Create a bar chart

plt.xlabel('Town')  # Label for the x-axis
plt.ylabel('Percentage')  # Label for the y-axis
plt.title('Percentage of Entries per Town')  # Title of the plot
plt.xticks(rotation=90)  # Rotate the x-axis labels for better visibility if needed
plt.show()

# %% [markdown]
# #### From the count plot above we can see that there are very little ales recoed in Central Area, Bukit Timah and Marine Parade(below 1%).therefore we are going to drop these data for our model training.

# %%
data = data[data['town'] != "CENTRAL AREA"]
data = data[data['town'] != "BUKIT TIMAH"]
data = data[data['town'] != "MARINE PARADE"]

# %% [markdown]
# #### Load the HDB location file, and join with the resale dataframe.  This will allow us to calculate the distance from the nearest mrt for each HDB blocks.

# %%
hdb_locations.rename(columns={"latitude": "lat", "longtitude": "lng",
                              "blk_no": "block", "RD_name": "street_name"},
                     inplace=True)
hdb_locations = hdb_locations[hdb_locations['postal.1'] != 189677]
hdb_locations = hdb_locations[hdb_locations['postal.1'] != 469277]
hdb_locations = hdb_locations[hdb_locations['postal'] != 90027]
hdb_locations = hdb_locations[["postal", "lat", "lng", "block", "street_name", "postal.1"]]
imputed_data = pd.merge(data, hdb_locations, how='left',
                        on=['block', 'street_name'])
imputed_data.dropna(inplace=True)

# %%
imputed_data.head()
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2019-01-01  ANG MO KIO    3 ROOM   225   ANG MO KIO AVE 1     01 TO 03
# 1 2019-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     01 TO 03
# 2 2019-01-01  ANG MO KIO    3 ROOM   440  ANG MO KIO AVE 10     04 TO 06
# 3 2019-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     10 TO 12
# 4 2019-01-01  ANG MO KIO    3 ROOM   637   ANG MO KIO AVE 6     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            67.0  New Generation                 1978               58
# 1            60.0        Improved                 1986               66
# 2            67.0  New Generation                 1979               59
# 3            61.0        Improved                 1986               66
# 4            68.0  New Generation                 1980               60
#
#    resale_price  year  price_per_sqm    postal       lat         lng  postal.1
# 0      230000.0  2019    3432.835821  560225.0  1.367396  103.838150  560225.0
# 1      235000.0  2019    3916.666667  560174.0  1.375097  103.837619  560174.0
# 2      238000.0  2019    3552.238806  560440.0  1.366428  103.854311  560440.0
# 3      240000.0  2019    3934.426230  560174.0  1.375097  103.837619  560174.0
# 4      240000.0  2019    3529.411765  560637.0  1.380362  103.842335  560637.0

# %% [markdown]
# ## Data Enrichment
# ### We will try to enrich the data by calculating the distance of the HDB from MRT stations as we think distance to mrt station might be a good predictor

# %% [markdown]
# #### Here we will clean the mrt_locations data to remove the unnecessary data

# %%
mrt_locations.head()
# Out:
#    Unnamed: 0  OBJECTID                    STN_NAME STN_NO  \
# 0           0         1           EUNOS MRT STATION    EW7
# 1           1         2  CHINESE GARDEN MRT STATION   EW25
# 2           2         3          KHATIB MRT STATION   NS14
# 3           3         4          KRANJI MRT STATION    NS7
# 4           4         5         REDHILL MRT STATION   EW18
#
#                                       geometry  Latitude   Longitude
# 0  POINT (103.9032524667383 1.319778951553637)  1.319779  103.903252
# 1  POINT (103.7325967380734 1.342352820874744)  1.342353  103.732597
# 2  POINT (103.8329799077383 1.417383370153547)  1.417383  103.832980
# 3  POINT (103.7621654109002 1.425177698770448)  1.425178  103.762165
# 4   POINT (103.816816670149 1.289562726402453)  1.289563  103.816817

# %%
mrt_locations.drop(columns=['Unnamed: 0', 'OBJECTID',
                            'geometry', "STN_NO", ], inplace=True)

# %%
mrt_locations.rename(columns={"Latitude": "lat", "Longitude": "lng"}, inplace=True)

# %%
mrt_locations.head()
# Out:
#                      STN_NAME       lat         lng
# 0           EUNOS MRT STATION  1.319779  103.903252
# 1  CHINESE GARDEN MRT STATION  1.342353  103.732597
# 2          KHATIB MRT STATION  1.417383  103.832980
# 3          KRANJI MRT STATION  1.425178  103.762165
# 4         REDHILL MRT STATION  1.289563  103.816817

# %% [markdown]
# #### This is the formula to convert from euclidean distance to earth distance
# #### Formula taken from https://byteshiva.medium.com/navigate-the-world-a-guide-to-calculating-distances-between-points-on-earth-using-python-and-the-9f3c5c856203

# %%
def calculate_distance(x, y):
    R = 6371  # Radius of the Earth in kilometers

    lat_a, lon_a = x[0], x[1]
    lat_b, lon_b = y[0], y[1]
    # Convert latitude and longitude to radians
    lat_a, lon_a, lat_b, lon_b = np.radians([lat_a, lon_a, lat_b, lon_b])

    # Calculate the difference in latitude and longitude
    dlat = lat_b - lat_a
    dlon = lon_b - lon_a

    # Apply the Haversine formula
    a = np.sin(dlat / 2) ** 2 + np.cos(lat_a) * np.cos(lat_b) * np.sin(dlon / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c

    return distance

# %% [markdown]
# #### Here we import the KNN package to calculate the distance between each HDB block and the nearest mrt

# %%
from sklearn.neighbors import KNeighborsClassifier

nbrs = KNeighborsClassifier(n_neighbors=1, algorithm='ball_tree',
                            metric=calculate_distance).fit(mrt_locations[['lat', 'lng']],
                                                           mrt_locations['STN_NAME'])

imputed_data['mrt_dist'] = nbrs.kneighbors(imputed_data[['lat', 'lng']])[0]

imputed_data['nearest_mrt'] = nbrs.predict(imputed_data[['lat', 'lng']])

# %%
imputed_data.head()
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2019-01-01  ANG MO KIO    3 ROOM   225   ANG MO KIO AVE 1     01 TO 03
# 1 2019-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     01 TO 03
# 2 2019-01-01  ANG MO KIO    3 ROOM   440  ANG MO KIO AVE 10     04 TO 06
# 3 2019-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     10 TO 12
# 4 2019-01-01  ANG MO KIO    3 ROOM   637   ANG MO KIO AVE 6     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            67.0  New Generation                 1978               58
# 1            60.0        Improved                 1986               66
# 2            67.0  New Generation                 1979               59
# 3            61.0        Improved                 1986               66
# 4            68.0  New Generation                 1980               60
#
#    resale_price  year  price_per_sqm    postal       lat         lng  \
# 0      230000.0  2019    3432.835821  560225.0  1.367396  103.838150
# 1      235000.0  2019    3916.666667  560174.0  1.375097  103.837619
# 2      238000.0  2019    3552.238806  560440.0  1.366428  103.854311
# 3      240000.0  2019    3934.426230  560174.0  1.375097  103.837619
# 4      240000.0  2019    3529.411765  560637.0  1.380362  103.842335
#
#    postal.1  mrt_dist               nearest_mrt
# 0  560225.0  0.541992     MAYFLOWER MRT STATION
# 1  560174.0  0.346258     MAYFLOWER MRT STATION
# 2  560440.0  0.585051    ANG MO KIO MRT STATION
# 3  560174.0  0.346258     MAYFLOWER MRT STATION
# 4  560637.0  0.329216  YIO CHU KANG MRT STATION

# %%
UniqueNames = imputed_data['town'].unique()

#create a data frame dictionary to store your data frames
DataFrameDict = {elem: pd.DataFrame() for elem in UniqueNames}

for key in DataFrameDict.keys():
    DataFrameDict[key] = imputed_data[imputed_data.town == key]
f = plt.figure(figsize=(20, 20))
for i in range(len(UniqueNames)):
    column = i // 5
    row = i % 5
    axis = f.add_subplot(5, 5, i + 1)
    dataset = UniqueNames[i]
    title = "town = " + dataset
    axis.scatter(DataFrameDict[dataset]['mrt_dist'],
                 DataFrameDict[dataset]['price_per_sqm'],
                 color='#1978b9',
                 edgecolors='white',
                 linewidth=0.5)
    axis.set_xlim([-0.2, 3.5])
    axis.set_ylim([1500, 13000])
    axis.set_xticks([0, 1, 2, 3])
    axis.set_title(title)

    if i >= 17:
        axis.set(xlabel='mrt_dist')
    else:
        axis.tick_params(colors='black', which='major', axis='x', labelcolor='white')
    if row == 0:
        axis.set(ylabel='price_per_sqm')

# %% [markdown]
# #### From the chart of price_per_sqm versus mrt_dist plot we generated for each town, we observed there is not a strong correlation between price and mrt distancefor most of the towns. Thus, the mrt_dist might be a useful predictor when training our model.

# %% [markdown]
# ### Visualisation
#
# ##### To visualise the hot spot where of hdb location and their distance to the mrt stations, we have plot the graph below resembling the Singapore map

# %%
map_town_data = pd.DataFrame({"Latitude": imputed_data["lat"],
                              "Longitude": imputed_data["lng"],
                              "Town": imputed_data["town"]})

train_map_data = pd.DataFrame({"Latitude": mrt_locations["lat"],
                               "Longitude": mrt_locations["lng"]})

custom_palette = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22',
                  '#17becf', '#9edae5', '#393b79', '#5254a3', '#6b6ecf', '#9c9ede', '#637939', '#8ca252', '#b5cf6b',
                  '#cedb9c', '#8c6d31', '#bd9e39', '#e7ba52']

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.scatterplot(x="Longitude", y="Latitude", hue="Town", data=map_town_data, palette=custom_palette)
sns.scatterplot(x="Longitude", y="Latitude", data=train_map_data, facecolor="red", edgecolor="white")
plt.legend(title="Towns in Singapore", loc="center left", bbox_to_anchor=(1, 0.5))

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Map of HDB resale flats with MRT & LRT  stations from the period of 2019 to 2023 by Towns in Singapore")

plt.show()

# %%
corr_matrix = imputed_data.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(corr_matrix)
plt.show()

# %% [markdown]
# #### From the heatmap shown above, we theorised that floor_area_sqm and remaining_lease will be a good predictor of resale price, while mrt_dist will not contribute much in predicting the resale_price

# %% [markdown]
# # Task 5: Modeling and visualization

# %% [markdown]
# #### Feature selection for model training
#
# ##### To reduce the complexity of the model and prevent model overfitting, we have discarded:
# ###### 1) features which are too sparse(block & street name)
# ###### 2) features which are similar(lease commence date) - the value is already calculated and represented by remaining lease

# %%
data = imputed_data[
    ["month", "town", "flat_type", "storey_range", "floor_area_sqm", "flat_model", "remaining_lease", "mrt_dist",
     "resale_price"]]

# %%
data.to_csv('output.csv', index=False)

# %% [markdown]
# #### Step 3: Modelling

# %% [markdown]
# #### 1) Linear Regression Model
#
# We train a linear regression model as a baseline where we will improve on it using more complicated models which utilises techniques such as cross validation, baggging, stacking and ensembling.

# %%
data = pd.read_csv('output.csv')

# %%
# Data preparation
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Split data into predictors and target
X = data.drop('resale_price', axis=1)
X = X.drop('month', axis=1)
y = data['resale_price']

# Split the dataset into training (90%) and test (10%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %% [markdown]
# #### Preprocessing for categorical features
#
# ##### Before piping the data into the regression model, we performi 1 hot encoding to transform Categorial data (which are text data) into one hot encoding to match the input format of the  Linear Regressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Define columns that need encoding
categorical_features = ['town', 'flat_type', 'storey_range', 'flat_model']

# OneHotEncoder for categorical data within a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'  # Include all other columns in the model unchanged
)

# Create a pipeline that includes preprocessing and the linear model
LR_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Train the model
LR_model.fit(X_train, y_train)

# Predict on the test data
y_pred = LR_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = (mean_squared_error(y_test, y_pred))**0.5

print('RMSE: {:.2f}'.format(rmse))
print('MAE: {:.2f}'.format(mae))
print('r2: {:.2f}'.format(r2))
# Out:
# RMSE: 79845.39
# MAE: 64428.02
# r2: 0.77

# %% [markdown]
# #### 2) Decision Tree
#
# With the baseline identified, we proceeded to experiment with more complex models such as DecisionTreeRegressor. The DecisionTreeRegressor is a versatile machine learning model used for regression tasks that predicts continuous outcomes by splitting data into increasingly homogeneous subsets. It constructs a tree-like model of decisions based on the values of the input features, making it highly interpretable and easy to visualize.
#
# By using the decision tree regressor, we are able to improve the RMSE from 79845 to 54105, with a 47% improvement.

# %%
from sklearn.tree import DecisionTreeRegressor

DT_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', DecisionTreeRegressor(random_state=42))
])

# Train the model
DT_model.fit(X_train, y_train)

# Predict on the test data
y_pred = DT_model.predict(X_test)

# Evaluate the model

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = (mean_squared_error(y_test, y_pred))**0.5

print('RMSE: {:.2f}'.format(rmse))
print('MAE: {:.2f}'.format(mae))
print('r2: {:.2f}'.format(r2))
# Out:
# RMSE: 54104.85
# MAE: 36034.01
# r2: 0.90

# %% [markdown]
# #### 3) Hyperparameter tuning on Decision Tree Regressor
#
# Then, the model is finetuned by optimizing the parameters that govern the training process. In the cell below, we test various combinations of hyperparameters to determine the most effective settings for the Decision Tree Regressor including, max_depth, min_samples_split and min_samples_leaf.
#
# It shows significant improvement (6.1%)  with the RMSE decreasing from 54105 to 50984.

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'regressor__max_depth': [None, 10, 20, 30],  # Maximum number of levels in each tree
    'regressor__min_samples_split': [2, 10, 20],  # Minimum number of samples required to split an internal node
    'regressor__min_samples_leaf': [1, 5, 10]  # Minimum number of samples required to be at a leaf node
}

grid_search = GridSearchCV(estimator=DT_model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5, verbose=1)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

best_model = grid_search.best_estimator_

# Predict on the test data
y_pred = best_model.predict(X_test)

# Evaluate the model

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = (mean_squared_error(y_test, y_pred))**0.5

print('RMSE: {:.2f}'.format(rmse))
print('MAE: {:.2f}'.format(mae))
print('r2: {:.2f}'.format(r2))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters: {'regressor__max_depth': None, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 10}
# Best score: -2702001284.5219145
# RMSE: 50984.10
# MAE: 34885.60
# r2: 0.91

# %% [markdown]
# ### Note: The below part is experimental and requires the installation of additional packages!

# %%
# !pip install autogluon
# !pip install -U scikit-learn==1.4.0
# Out:
# Requirement already satisfied: autogluon in c:\users\wongs\anaconda3\envs\general\lib\site-packages (1.1.0)
# Requirement already satisfied: autogluon.core==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.features==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.tabular==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: autogluon.multimodal==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.timeseries==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: numpy<1.29,>=1.21 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.24.3)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.12.0)
# Requirement already satisfied: scikit-learn<1.4.1,>=1.3.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: networkx<4,>=3.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.1)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.65.0)
# Requirement already satisfied: requests in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.8.4)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.89)
# Requirement already satisfied: autogluon.common==1.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: ray<2.11,>=2.10.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<11,>=10.0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (10.2.0)
# Requirement already satisfied: torch<2.2,>=2.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: transformers<4.39.0,>=4.38.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (4.19.2)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.4.1)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.1.3)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.0.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.7.14)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (4.3.0)
# Requirement already satisfied: catboost<1.3,>=1.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.2.5)
# Requirement already satisfied: joblib<2,>=1.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (1.2.0)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (3.10.1)
# Requirement already satisfied: optimum<1.19,>=1.17 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (5.9.0)
# Requirement already satisfied: setuptools in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from autogluon.common==1.1.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (60.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (23.2)
# Requirement already satisfied: pyyaml in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (6.0.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.89 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.34.89)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (5.21.0)
# Requirement already satisfied: six in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2.18.0)
# Requirement already satisfied: dill in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.3.6)
# Requirement already satisfied: xxhash in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.70.14)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2023.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.20.3)
# Requirement already satisfied: responses<0.19 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.13.3)
# Requirement already satisfied: pip in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (23.3.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.5.29)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.7.4)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.7.0)
# Requirement already satisfied: toolz~=0.10 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (4.9.0)
# Requirement already satisfied: future in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: py4j in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.0->autogluon) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.10.6)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from lightning<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (0.11.2)
# Requirement already satisfied: numba in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.59.1)
# Requirement already satisfied: window-ops in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (5.1.0)
# Requirement already satisfied: click in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (2023.10.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.0->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.9.0)
# Requirement already satisfied: coloredlogs in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (15.0.1)
# Requirement already satisfied: sympy in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.12)
# Requirement already satisfied: onnx in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.11.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.17.3)
# Requirement already satisfied: protobuf>=3.20.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2023.3)
# Requirement already satisfied: filelock in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.13.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.0.8)
# Requirement already satisfied: aiosignal in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray<2.11,>=2.10.0->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.9.3)
# Requirement already satisfied: aiohttp-cors in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.7.0)
# Requirement already satisfied: colorful in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.14)
# Requirement already satisfied: opencensus in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.14.1)
# Requirement already satisfied: smart-open in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.4.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (20.25.3)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.62.2)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (14.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from requests->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2024.2.2)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2.34.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (2.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.0.2)
# Requirement already satisfied: safetensors in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.0->autogluon) (0.4.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from transformers<4.39.0,>=4.38.0->transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.15.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from matplotlib->autogluon.core==1.1.0->autogluon.core[all]==1.1.0->autogluon) (3.0.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.9.3)
# Requirement already satisfied: pyarrow-hotfix in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (4.12.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from numba->mlforecast<0.10.1,>=0.10.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.42.0)
# Requirement already satisfied: flatbuffers in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (24.3.25)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.18.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.3.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries==1.1.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (3.10.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (10.0)
# Requirement already satisfied: ordered-set in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.18.0)
# Requirement already satisfied: pycryptodome in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.20.0)
# Requirement already satisfied: openxlab in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.38)
# Requirement already satisfied: pywin32 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from plotly->catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from sympy->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (2.29.0)
# Requirement already satisfied: pyreadline3 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from humanfriendly>=9.1->coloredlogs->optimum<1.19,>=1.17->optimum[onnxruntime]<1.19,>=1.17; extra == "all"->autogluon.timeseries[all]==1.1.0->autogluon) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (2.5)
# Requirement already satisfied: oss2~=2.17.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from requests[socks]->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (4.9)
# Requirement already satisfied: crcmod>=1.7 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: cryptography>=2.6.0 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (42.0.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0; extra == "all"->autogluon.core[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\wongs\anaconda3\envs\general\lib\site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.21)

# %% [markdown]
# #### 4) AutoML
#
# By referring to the paper [AutoGluon-Tabular](https://arxiv.org/pdf/2003.06505.pdf), we have tried the best performing AutoML model which is able to automatically select relevant models based on our modelling task (regression) such as KNN, RandomForest, LightGBM, XGBoost. Then, a final model is trained using ensembling where the output of the most performant models are weighted.
#
# By doing so, we are able to reduce the RMSE from 50984 to 25716.

# %% [markdown]
# ![Local Image](./images/AutoGluon_Ensembling.png)

# %%
# Initialisation
from autogluon.tabular import TabularDataset, TabularPredictor

# Train test split
train, test = train_test_split(data, test_size=0.1, random_state=0)
train_data = TabularDataset(train)
test_data = TabularDataset(test)

# %%
label = 'resale_price'
save_path = './AutogluonModels/small'
try:
    predictor = TabularPredictor.load(save_path)
except:
    # Retraining will take around 60 seconds
    presets = ['good_quality', 'optimize_for_deployment']
    predictor = TabularPredictor(label=label, path=save_path).fit(train_data, presets=presets, time_limit=60)

# %%
predictor.evaluate(test_data)
# Out:
# {'root_mean_squared_error': -28650.780324820356,
#  'mean_squared_error': -820867213.2211133,
#  'mean_absolute_error': -20450.017244982548,
#  'r2': 0.9707724441181854,
#  'pearsonr': 0.9852810733672099,
#  'median_absolute_error': -14724.5625}

# %%
results = predictor.evaluate(test_data)

print('RMSE: {:.2f}'.format(-results['root_mean_squared_error']))
print('MAE: {:.2f}'.format(-results['mean_absolute_error']))
print('r2: {:.2f}'.format(results['r2']))
# Out:
# RMSE: 28650.78
# MAE: 20450.02
# r2: 0.97

# %% [markdown]
# #### Feature importance
# By calculating the feature importance scores for the given model via permutation importance, we found that the town and flat_type of the hdb flat have the highest importance when predicting the resale price.

# %%
predictor.feature_importance(test_data)
# Out:
#                     importance       stddev       p_value  n       p99_high  \
# town             106068.756376  1667.738286  7.331617e-09  5  109502.652558
# flat_type         85959.846495  1352.574806  7.353609e-09  5   88744.816715
# month             59488.467628   473.545541  4.817929e-10  5   60463.504443
# remaining_lease   57255.777302  1188.005105  2.222941e-08  5   59701.896234
# floor_area_sqm    43517.972184  1176.790124  6.410315e-08  5   45940.999314
# flat_model        24563.499687   502.472489  2.100038e-08  5   25598.097487
# mrt_dist          18048.738272   713.642695  2.926930e-07  5   19518.138445
# storey_range      16548.739849   652.336897  2.891413e-07  5   17891.910536
#
#                        p99_low
# town             102634.860194
# flat_type         83174.876276
# month             58513.430813
# remaining_lease   54809.658370
# floor_area_sqm    41094.945054
# flat_model        23528.901888
# mrt_dist          16579.338099
# storey_range      15205.569161

# %% [markdown]
# ## Demo
#
# ##### With the trained model, we are able to test out our model for our potential users (potential buyer searching for HDB flat near NUS on PropertyGuru):

# %%
# Search criteria: a relatively new house near NUS
month = '2024-04-24'
town = 'CLEMENTI'
flat_type = '3 ROOM'
storey_range = '10 TO 12'
floor_area_sqm = 90
flat_model = 'New Generation'
remaining_lease = 90
mrt_distance = 1.0

# hdb_search = data.sample(1)

hdb_search = pd.DataFrame([[month, town, flat_type, storey_range, floor_area_sqm, flat_model, remaining_lease, mrt_distance]] , columns = ["month", "town", "flat_type", "storey_range", "floor_area_sqm", "flat_model", "remaining_lease", "mrt_dist"])
hdb_search
# Out:
#         month      town flat_type storey_range  floor_area_sqm  \
# 0  2024-04-24  CLEMENTI    3 ROOM     10 TO 12              90
#
#        flat_model  remaining_lease  mrt_dist
# 0  New Generation               90       1.0

# %%
predictor.predict(hdb_search)
# Out:
# 0    629813.625
# Name: resale_price, dtype: float32

# %% [markdown]
# ## Conclusion
#
# In the data preparation stage, we selected the most relevant data by filtering out the outliers. We also enriched the data by calculating the distance of mrt to hdb.
#
# In the EDA stage, we visualised the data to have a better understanding of the data and plotted a correlation matrix in a heatmap. We also preprocessed the data by applying one hot encoding on categorical data.
#
# In the modelling stage, we saw that even simple model like linear regression can get a relatively good prediction. However, we found out that more complex model just as Decision Tree Regression is able to get a better results, and can be further enhance using hyperparameter tuning. Lastly, we also tried out the state of the art model which utilises ensembling for best model performance.
#
# In the feature importance analysis, we also confirmed our hypothesis when calculating the correlation matrix, where mrt_distance does not really contribute in the prediction of sales price.
#
# In conclusion, we have successfully trained a highly accurate sales price prediction model with a 5.1% error (RMSE = 25716, mean = 507,654) after going through the steps of EDA, data enrichment, data preparation and modelling.
